# %% [markdown]
# ## Kristen Shen First Draft: Flavors of E-cigarattes

# %%
#set up

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# import the file

# %%
df = pd.read_csv('e-cigarette-data.csv')
df.head()
# Out:
#    year          flavor  weighted_percent
# 0  2023  Tobacco-flavor               0.5
# 1  2023         Menthol               1.4
# 2  2023            Mint               2.0
# 3  2023           Spice               0.4
# 4  2023           Fruit               4.4

# %%
# %%R
#
# require('ggplot2')
# require('readr')
# require('dplyr')
# require('tidyr')
# Out:
# Loading required package: ggplot2
# Loading required package: readr
# Loading required package: dplyr
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Loading required package: tidyr

# %%
# %%R
#
# # Read data
# df <- read_csv('e-cigarette-data.csv')
# df
# Out:
# Rows: 31 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): flavor
# dbl (2): year, weighted_percent
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# # A tibble: 31 × 3
#     year flavor              weighted_percent
#    <dbl> <chr>                          <dbl>
#  1  2023 Tobacco-flavor                   0.5
#  2  2023 Menthol                          1.4
#  3  2023 Mint                             2
#  4  2023 Spice                            0.4
#  5  2023 Fruit                            4.4
#  6  2023 Chocolate                        0.4
#  7  2023 Alcoholic drinks                 0.6
#  8  2023 Non-alcoholic drink              0.8
#  9  2023 Sweets                           2.4
# 10  2023 Unflavored                       0.8
# # ℹ 21 more rows
# # ℹ Use `print(n = ...)` to see more rows

# %%
# %%R
#
# # Plot +
# # Aesthetics
# ggplot(df) +
#     aes(y= weighted_percent, x=year) +geom_point() + facet_wrap(~flavor)

# %%
df.columns
# Out:
# Index(['year', 'flavor', 'weighted_percent'], dtype='object')

# %%
df_new = df[(df['flavor'] != 'Unflavored') & (df['flavor']!='Tobacco-flavor') & (df['flavor']!='Non-alcoholic drink')]
df_new
# Out:
#     year            flavor  weighted_percent
# 1   2023           Menthol               1.4
# 2   2023              Mint               2.0
# 3   2023             Spice               0.4
# 4   2023             Fruit               4.4
# 5   2023         Chocolate               0.4
# 6   2023  Alcoholic drinks               0.6
# 8   2023            Sweets               2.4
# 10  2022           Menthol               2.0
# 11  2022              Mint               2.3
# 12  2022            Spice                0.2
# 13  2022             Fruit               5.1
# 14  2022        Chocolate                0.3
# 15  2022  Alcoholic drinks               0.6
# 16  2022            Sweets               2.9
# 17  2021           Menthol               1.7
# 18  2021              Mint               1.8
# 19  2021            Spice                0.1
# 20  2021             Fruit               4.2
# 21  2021        Chocolate                0.2
# 22  2021  Alcoholic drinks               0.4
# 23  2021            Sweets               2.1
# 24  2020           Menthol               3.7
# 25  2020              Mint               5.7
# 26  2020            Spice                0.2
# 27  2020             Fruit               7.7
# 28  2020        Chocolate                0.5
# 29  2020  Alcoholic drinks               0.6
# 30  2020            Sweets               4.0

# %%
df_new.to_csv('new_flavor.csv', index=False)

# %%
df_new = pd.read_csv('new_flavor.csv')
df_new.head()
# Out:
#    year     flavor  weighted_percent
# 0  2023    Menthol               1.4
# 1  2023       Mint               2.0
# 2  2023      Spice               0.4
# 3  2023      Fruit               4.4
# 4  2023  Chocolate               0.4

# %%
# %%R
#
# # Read data
# df_new <- read_csv('new_flavor.csv')
# df_new
# Out:
# Rows: 28 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): flavor
# dbl (2): year, weighted_percent
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# # A tibble: 28 × 3
#     year flavor           weighted_percent
#    <dbl> <chr>                       <dbl>
#  1  2023 Menthol                       1.4
#  2  2023 Mint                          2
#  3  2023 Spice                         0.4
#  4  2023 Fruit                         4.4
#  5  2023 Chocolate                     0.4
#  6  2023 Alcoholic drinks              0.6
#  7  2023 Sweets                        2.4
#  8  2022 Menthol                       2
#  9  2022 Mint                          2.3
# 10  2022 Spice                         0.2
# # ℹ 18 more rows
# # ℹ Use `print(n = ...)` to see more rows

# %%
# %%R -w 1000 -h 500
# # Create a dataset for labeling (only keep the last year for each flavor)
# df_labels <- df_new %>% group_by(flavor) %>% filter(year == max(year))
#
# # Define custom colors
# custom_colors <- c("Menthol" = "deepskyblue", "Mint" = "aquamarine1",
#                    "Fruit" = "green", "Spice" = "orange",
#                    "Chocolate" = "deeppink4", "Alcoholic drinks" = "darkgrey", "Sweets" = "blueviolet")
#
# # Create the plot with labels on the chart
# ggplot(df_new, aes(x = year, y = weighted_percent, color = flavor, group = flavor)) +
#     geom_line(size = 1, alpha = 0.7) +
#     geom_point(size = 3) +              # Add scatter points
#     scale_color_manual(values = custom_colors) +  # Apply custom colors
#     geom_text(data = df_labels, aes(label = flavor), nudge_x=0.1, nudge_y=0, hjust = 0.1, size = 4, fontface = "bold") +
#     scale_x_continuous(limits = c(min(2020), max(2023) + 0.5))+
#     labs(
#         title = "Flavor Trends Over the Years",
#         x = "Year",
#         y = "Weighted Percentage"
#     ) +
#     theme_minimal() +
#     theme(
#         plot.title = element_text(hjust = 0.5, size = 16, face = "bold"),
#         axis.text = element_text(size = 12),
#         axis.title = element_text(size = 14),
#         legend.position = "none"
#     )
